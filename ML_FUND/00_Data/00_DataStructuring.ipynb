# %%
#                    PROJECT
#                       │
#                       ▼
#          Cookiecutter Data Science : python -m cookiecutter https://github.com/drivendata/cookiecutter-data-science -c v1

#                       │
#                       ▼
#               Project Structure
#                       │
#                       ├── data/
#                       ├── src/
#                       ├── notebooks/
#                       ├── models/
#                       └── docs/
#                              │
#                              ▼
#                            Sphinx
#                              │
#                              ▼
#                      HTML Documentation
#                              │
#                              ▼
#                           GitHub
#                              │
#                              ▼
#                       GitHub Actions
#                              │
#                              ▼
#                       GitHub Pages
#                              │
#                              ▼
#                    Documentation Website
