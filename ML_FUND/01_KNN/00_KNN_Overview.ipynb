# %%
# Q: How does KNN work and what should I check when building a KNN model? (Algorithm)

# For KNN clasify & KNN regression:
# New sample
# Calculate distances
# Find nearest neighbors
# Select K neighbors
# Vote with mode method (classification) / Average with mean (regression)
# Prediction

# %%
# What is a good workflow for a KNN model?

# 1. Clean data and handle missing values
# 2. Select useful features and remove outliers
# 3. Scale features 
# 4. Choose distance metric 
# 5. Choose K 
# 6. Validate the model 
# 7. Check performance metrics

# %%
# Q: How do interpolation and extrapolation relate to KNN?

# Interpolation:
# Predict inside the region covered by training data
# KNN works naturally because nearby data points exist

# Extrapolation:
# Predict outside the region covered by training data
# KNN has weaker evidence because nearby points may not exist

# KNN doesn't learn the road ahead; it looks at the nearest points around you

# %%
# Q: How should categorical data be handled in KNN?

# KNN relies on distance, so categorical features need a meaningful representation.

# Categorical data
# Encode appropriately
# Make sure distance is meaningful
# Scale numeric features if needed
# Choose a suitable distance metric
# Validate KNN

# Avoid:
# Red : 0
# Blue : 1
# Green : 2
# Because these numbers create an artificial order/distance.

# One-Hot Encoding:
# Red   : [1, 0, 0]
# Blue  : [0, 1, 0]
# Green : [0, 0, 1]
