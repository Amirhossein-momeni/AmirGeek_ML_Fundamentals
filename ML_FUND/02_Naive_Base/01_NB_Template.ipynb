# %%
import pandas as  pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#==============================================================================
# Reading DataSet
#==============================================================================

# Load dataset
URL = "https://raw.githubusercontent.com/Amirhossein-momeni/AmirGeek_ML_Datasets/refs/heads/main/DataSet/02-Titanic-Dataset.csv"
dataset = pd.read_csv(URL)

# Defining x and y
x = dataset.iloc[:, 2:].values
y = dataset.iloc[:, 1].values
